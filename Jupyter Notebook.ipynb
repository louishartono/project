# %%
import sys 
import os
#import pandahelper as pdh


import cymetric as cym
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (40,24)
from cymetric import graphs as cgr
from cymetric import timeseries as tm
from cymetric import filters as fl



# %matplotlib inline
#%pylab inline
#pylab.rcParams['figure.figsize'] = (40, 24)

SMALL_SIZE = 25
MEDIUM_SIZE = SMALL_SIZE+2
BIGGER_SIZE = MEDIUM_SIZE +2

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
f_h5 = "/home/louishartono/synthetic_history/civ_mil_A0/main.sqlite"
db_h5 = cym.dbopen(f_h5)
ev_h5 = cym.Evaluator(db=db_h5, write=True)

# %%
#cym.graphs.flow_graph(ev_h5)

# %%
#ev_h5.known_tables

# %%
#ev_h5.eval("AgentEntry")

# %%
#fl.inventories(evaler=ev_h5, facilities=['mil_str_u_dep'])#, nucs=['238pu'])

# %%
#fl.transactions(evaler=ev_h5, senders=['conversion'], receivers=['mil_enrichment'])#, commodities=['conversion'])

# %%
#data=[]
#df= fl.inventories(evaler=ev_h5)
#power = tm.get_power(evaler=ev_h5).set_index('Time').Value
#for i in range(360):
#    x = df.loc[df['Time'] == i, 'Quantity'].sum() / power[i]
#    data.append({"Time":i, "Quantity per Power":x})
#pd.DataFrame(data).set_index("Time")

# %%
#df= fl.inventories(evaler=ev_h5)
#df

# %%
#power = tm.get_power(evaler=ev_h5).set_index('Time').Value
#power

# %%
#data=[]
#df= fl.inventories(evaler=ev_h5)
#get_power = tm.get_power(evaler=ev_h5).set_index('Time').Value
#for i in range(12393):
#    power = get_power [df.Time [i]]
#    df.Quantity[i] = df.Quantity[i] / power
#df

# %%
#data=[]
#df= fl.transactions_nuc(evaler=ev_h5)
#get_power = tm.get_power(evaler=ev_h5).set_index('Time').Value
#for i in range(2828):
#    power = get_power [df.Time [i]]
#    df.Mass[i] = df.Mass[i] / power
#df

# %%
ev_h5.eval("InventoryQuantityPerGWe")
# Out:
#                                      SimId  AgentId  Time      InventoryName  \
# 0     fd6152c1-c24c-4882-ae98-365c93fcc13a       29     1      feed-inv-name
# 1     fd6152c1-c24c-4882-ae98-365c93fcc13a       29     1      feed-inv-name
# 2     fd6152c1-c24c-4882-ae98-365c93fcc13a       29     1      feed-inv-name
# 3     fd6152c1-c24c-4882-ae98-365c93fcc13a       29     2      feed-inv-name
# 4     fd6152c1-c24c-4882-ae98-365c93fcc13a       29     2      feed-inv-name
# 5     fd6152c1-c24c-4882-ae98-365c93fcc13a       29     2      feed-inv-name
# 6     fd6152c1-c24c-4882-ae98-365c93fcc13a       29     2  leftover-inv-name
# 7     fd6152c1-c24c-4882-ae98-365c93fcc13a       29     2  leftover-inv-name
# 8     fd6152c1-c24c-4882-ae98-365c93fcc13a       29     2  leftover-inv-name
# 9     fd6152c1-c24c-4882-ae98-365c93fcc13a       29     3      feed-inv-name
# 10    fd6152c1-c24c-4882-ae98-365c93fcc13a       29     3      feed-inv-name
# ...

# %%
ev_h5.eval("ExplicitInventory")
# Out:
#                                       SimId  AgentId  Time      InventoryName  \
# 0      fd6152c1-c24c-4882-ae98-365c93fcc13a       29     1      feed-inv-name
# 1      fd6152c1-c24c-4882-ae98-365c93fcc13a       29     1      feed-inv-name
# 2      fd6152c1-c24c-4882-ae98-365c93fcc13a       29     1      feed-inv-name
# 3      fd6152c1-c24c-4882-ae98-365c93fcc13a       29     2      feed-inv-name
# 4      fd6152c1-c24c-4882-ae98-365c93fcc13a       29     2      feed-inv-name
# 5      fd6152c1-c24c-4882-ae98-365c93fcc13a       29     2      feed-inv-name
# 6      fd6152c1-c24c-4882-ae98-365c93fcc13a       29     2  leftover-inv-name
# 7      fd6152c1-c24c-4882-ae98-365c93fcc13a       29     2  leftover-inv-name
# 8      fd6152c1-c24c-4882-ae98-365c93fcc13a       29     2  leftover-inv-name
# 9      fd6152c1-c24c-4882-ae98-365c93fcc13a       30     2      feed-inv-name
# 10     fd6152c1-c24c-4882-ae98-365c93fcc13a       30     2      feed-inv-name
# ...
